# %%
from bs4 import BeautifulSoup as bs
import requests
import csv

# %%
url='https://www.amazon.co.uk/All-New-Fire-Tablet-Alexa-Display/product-reviews/B07952CV7L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

# %%
def getdata(url):
    headers = {
            'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36' 
        }
    req = requests.get(url, headers = headers)
    soup = bs(req.content,'html.parser')
    title = soup.find_all('a',class_='review-title-content')
    title_up=[i.get_text() for i in title]
    title_up[:]=[i.lstrip('\\n') for i in title_up]
    title_up[:]=[i.rstrip('\\n') for i in title_up]
	
    desc=soup.find_all('span','review-text-content')
    desc_up=[i.get_text() for i in desc]
    desc_up[:]=[i.lstrip('\\n') for i in desc_up]
    desc_up[:]=[i.rstrip('\\n') for i in desc_up]
	
    star=soup.find_all('i','review-rating')
    star_up=[j.get_text() for i in star for j in i]
    star_upd=star_up[2:len(star_up)]

    name = soup.find_all('span','a-profile-name')
    name_upd=[name[i].get_text() for i in range(2,len(name))]

    date=soup.find_all('span','review-date')
    date_up,date_up1=[i.get_text() for i in date],[]
    for i in date_up:
        date_up1.append((i).strip('Reviewed in the United Kingdom on '))
        date_upd=date_up1[2:len(date_up1)]
    for i in range(len(title_up)):
	#This appends the specific information into CSV
        csv=[]
        csv.append(title_up[i])
        csv.append(desc_up[i])
        csv.append(star_upd[i])
        csv.append(name_upd[i])
        csv.append(date_upd[i])
        writer.writerow(csv)
        print(csv)
        return soup

# %%
def getnext_page(soup):
	#This will return the next page URL
	pages = soup.find('ul', {'class': 'a-pagination'})
	if not pages.find('li', {'class': 'a-disabled a-last'}):
		url = 'https://www.amazon.co.uk' + str(pages.find('li', {'class': 'a-last'}).find('a')['href'])
		return url #RETURNS NEXT PAGE URL
	else:
		return

# %%
file=open("/home/skk/Desktop/Amazon_Reviews","w") # USE YOUR LOCAL PATH
writer=csv.writer(file)
writer.writerow(["Title","Description","Stars","Review by","Date"])
# Out:
# 40

# %%
while True:
    data=getdata(url)
    url = getnext_page(data)
    if not url:
        break
# Out:
# ["\nCan't complain or moan at all!!\n", "\n\n  I paid £59.99 for this tablet so really for that price I can't see how anyone can give less than 5 stars or a negative review! Buy any other tablet for that price that can compare to this I challenge you..why oh why some people are moaning about it is beyond me, it states quite clearly in the write up what it is /does/specs etc and really if you want 'better' then spend more money and stop thinking you are going to get 'the elite' of all tablets for this sort of money! Brilliant tablet and definitely worth twice the money Amazon are asking. Great sound, screen, performance, love the colour and ease of use. Thank you Amazon.. I for one would certainly not insult your intelligence by saying anything negative about this tablet..but then I don't enjoy drama and moaning.P.S...I also own an ipad 2017, an ipad mini 4, a Samsung tab s4, a lenovo yoga Pro, lenovo tab 4 and a Huawei media pad m5 ..and this fire tablet compete's well!\n\n", '5.0 out of 5 stars', 'barbara east', '23 October 2018']
# ['\nTotal junk - a scam, don’t buy, the purchase i most regret in life\n', '\n\n  Possibly the worst purchase of my entire life. Just a scam. It’s impossible to add subscriptions to magazines you already have to this product. It basically tries to force you to buy all your subscriptions through amazon. It’s not good enough to use as a multi media device & they won’t let you download apps or transfer magazine subscriptions. You are locked into buying everything through amazon. In its gone in the bin & the money written off.. It’s junk. Definitely the worst purchase of my adult life & will never buy another amazon made product as long as I live. DO NOT BUY ONE OF THESE UNLESS YOU ARE PREPARED TO BUY EVERYTHING THROUGH AMAZON.\n\n', '1.0 out of 5 stars', 'max sheppard', '8 December 2018']
# ['\nVery good - at the price\n', '\n\n  Any review of a tablet produced at this price point needs to make allowances, due to its incredible value for money. It is well built but not elegant. The screen is reflective and not very sharp. All acceptable at the price. However, a real drawback is just how sluggish certain apps are to open. Some - Sonos and Spority for example I am about to give up on when they eventually begin to open and populate. This slowness is really the only thing that stops me giving a whole hearted recommendation.Disclaimer - I have been an iPad user for years. An iPad is in a completely different league - from a different planet. But then an iPad can be 5x more expensive. You really do get what you pay for. Fortunately I just brought this Fire as a cheap controller for my Sonos speaker system and music library.\n\n', '3.0 out of 5 stars', 'pgauntlett', '26 October 2018']
# ['\nExceeded my expectations!  Fantastic value for money!\n', '\n\n  I like the iPad. My husband is happy with tablets. We all use iPads apart from my husband! I bought this budget tablet a few days ago after our computer broke, purely for my 13yr old autistic son to use for spell zone and sam learning. (He uses his iPad for watching things and playing games and is very rigid about not using it for educational purposes). I wasn’t expecting much but have been pleasantly surprised! This fire is roughly the size of an iPad mini, was really easy to set up, runs at a good speed (so far) and is doing exactly what I wanted it to do.  My son chose the yellow version and I bought the yellow case to match. I will see how we go with this but I’m extremely tempted to buy myself one  and will do so if this continues to work as well as it has so far. For an inexpensive tablet you literally cannot go wrong! It’s not an iPad but it’s also not £400 upwards so for £60 I’m a very happy customer and recommend it!\n\n', '5.0 out of 5 stars', 'Laura from London', '23 December 2018']
# ['\nGreat Kindle, crap tablet\n', "\n\n  The Fire HD screen is great for the Kindle app. That's it. The rest of the Fire HD tablet features are a waste as the Fire OS is so limiting. Amazon are trying to create a captive market with this device and it's like using a kid's toy compared to any other tablet The Amazon apps are crap. Maps, Email etc are too basic to be useful in the modern world. Android apps that you can get for the Fire are limited in quantity and quality. No LinkedIn app. No PayPal app. Facebook app doesn't work properly. Silk browser is slow and you can't even replace it with Firefox or Opera. No Indeed or CV Library apps for job seekers. EVEN THE AMAZON STORE APP DOESN'T WORK PROPERLY.You can't disable any Amazon apps that you don't use so they carry on running in the background and slow the performance down. No Google play store so no access to apps that would work on any other Android device.No wonder people are working so hard to work out a way of rooting the Fire HD 8. It's a disappointing tablet that tries to make you but more from its supplier. Come on Amazon. Give us a tablet that works instead of an expensive tea tray.\n\n", '1.0 out of 5 stars', 'Mark Hale', '25 December 2018']
# ['\nExcellent quality and value. Highly recommended.\n', "\n\n  I love this little tablet! I have been pleasantly surprised at how good the graphics are on thisFire 8HD. When I first saw it, the wallpaper didn't do it justice at all as the set picture was dull and grainy but as soon as I updated to a full hd wallpaper and started watching films and playing games, I saw the real quality. Great colour and sharpness!I added a 128gb SD card to store films etcThe stereo sound is impressive. Quite loud and clear!Reading is great too. Kindle remembers where you are in your book on any device and gives you the option to carry on reading from that point. The screen is sharp and clear with an option for a 'blue light' filterI'm using this tablet for all my entertainment and it gives other tablets, of many times the price, a good run for the money.You can install Netflix, Plex, Prime Video, all your favourites.Even Google Playsuits if you wish.This is an Android based tablet and as such, extremely versatile.Oh, and the added benefit of Alexa at your fingertips - you can even put her in show mode for screening news or recipes or whatever!Great tablet for a small amount of money.Highly recommended.\n\n", '5.0 out of 5 stars', 'Offtheplanet', '20 August 2019']
# ["\nAmazon's app store is very poor, and it's all this tablet can work with.\n", "\n\n  I've bought this tablet mainly in order to read--not only Kindle books. But there are very few apps that work on it. E.g., the Economist and other papers don't work. It is true that got good reviews and it's very cheap, but if you wish to use it for reading--don't try.\n\n", '1.0 out of 5 stars', 'M. Keren', '15 December 2018']
# ['\nGood for the money paid, though slow reaction time and takes too long to charge.\n', "\n\n  I think for the price paid that this tablet is fine and does the job. I only use it to watch my Netflix, BBC iPlayer and Prime videos while I commute to and from work and also sitting next to me while I use my laptop for doing other things. I wouldn't want to carry a more expensive tablet around with me during the day. I sometimes use it for reading my books too but I find that my Kindle Paperwhite is more suited for this; feels more authentic and comfortable for book reading. I do love the sound and screen quality and getting the Fire 8 seems to be perfect choice in terms of screen size as the 7 a bit too small for me (my mum has one so I checked that out first) and the 10 definitely too big for commuting I think.For me, there are a couple of issues that I'm still trying to get my head around. It has a slow reaction time (you need to have some patience with this) and it takes an absolute age to charge. I thought maybe there's something I'm doing wrong which means it takes a while to charge, so I've posted a question separately about this and hopefully someone can help me. I try to dim the screen and close all applications that are running in the background but it still takes a while. For example, it's midnight at the moment I write this and I put it on charge at 6.30pm when it was down to 10 per cent. Still 5 hours later it's only up to 80 per cent charge. I am needing to leave the tablet charging overnight so that I can use it again the next morning, not something I like doing as think leaving things on overnight can be dangerous :(\n\n", '4.0 out of 5 stars', 'samanthadott', '23 November 2018']
# ['\nA value-for-money Android Tablet, with Amazon-y bits\n', "\n\n  At this price point (especially as it's currently discounted to £54), this tablet is an excellent purchase. Personally, I don't find the lock screen adverts at all bothering, and the daily addition of a recommendaed app on the Home screen is soon removed (about 10s). So, the extra £10 to have these removed doesn't seem worth it to me at the moment.The tablet itself is built to a price point, which is to be expected, and may not survive dropping if a corner hit the ground. I bought a case (for £8.99) and have been very happy with the combination. I bought an SD card at the same time, so my total purchase price for the tablet, case and 64GB SD card was just over £70. That's quite a decent bargain.After some Google Fu, I loaded up the Google Play Store with no trouble at all, and with no interference to the usual Fire apps - they just work in parallel. That allowed me access to few extra things that I wanted (Chrome, Gmail, YouTube, etc.) and so far all has worked really well and I have a fantastic sofa-surfing machine.Personally, I found that I had to turn the screen brightness all the way up (and turn off adaptiveness) to get the most from it, but it's plenty good enough to watch iPlayer, Netflix and Amazon Prime. The sound is pretty good too, although I had to turn it all the way up on speakers - maybe I'm just deaf.I have used it for Skype video calls and it performed really well. The camera aren't great for photography (but then it's hardly ergonomically designed to be used as one), but more than good enough for a video call. The sound through a headset was great as well.Overall, it's excellent value-for-money and gives me exactly what I wanted to be able to do simple surfing on the sofa and play video/audio content when I'm working on my main machine. The cheap case worked well and you can still see the bright yellow case as a trim, so I'm pleased with that combination.I've gone for 5 stars as it has done everything that I've wanted so far and for a very good price. It's not the most sleek design, but basically it's a tablet and I won't cry (too much) if I drop it.\n\n", '5.0 out of 5 stars', 'AndyB99', '2 September 2019']
# ['\nGet a different reader\n', '\n\n  Disappointing had the previous kindle fire for 5 years. Seems that in that time all amazons efforts in development of the kindle have been aimed at locking the device even more tightly to the Amazon store so you can only purchase from there, and in providing a marketing tool to bombard customers with junk. The only aspect of the original kindle firebHD interface which was genuinely novel and attractive, i.e the seamless scroll wheel through all apps and books has inexplicable been removed . I can only assume to ensure improved marketing opportunities offered by hard wiring  other apps to the home page. I think this device is designed with Amazon in mind and not its customers!The support is confused and unabe to deliver solutions to basic probkems. The spell checker has to be disabled unless you want to spend your time correct the start of every email from "Fear" to "Dear". the Longstanding issues navigating the device and locating files remain unaddressedBasically rubbish.\n\n', '1.0 out of 5 stars', 'David Snead', '1 June 2019']
# ['\nCheap, but fiddly/frustrating to use, a cluttered, uncontrollable mess. Buy something better.\n', "\n\n  Reviewing this from the point of view of a parent of Y2 children. Yes, it's cheap. But, it's frustrating to use. Slick it is not. It is the entry level tablet for entry level tablets. You can't get more basic than this. But it has good parental controls and supports multiple profiles. And it was only about £60.Likes:Multiple profilesParental controls and setting time limitsAdding customisable list of websites (for young children)Age-related contentCheap as chips (although the quality reflects this)Dislikes:Fiddly settingsIncredibly messy home screens set by Amazon that can't be changedAdverts when switching between profiles meaning entering your PIN twiceTwo icons for web browsers: one called 'internet' another called 'Silk' but both appear to be the same (why??)Despite enabling web browser for children's profile a web browser doesn't appear - meaning that the websites you added for your children's profiles cannot be accessedDespite promises of 'thousands of age-related websites' there are only a few (are the rest in the missing browser? Who knows...Amazon adding Kids Unlimited probably because I clicked on something (Amazon has a history of adding stuff without you realising - see Amazon Prime). This may be from the initial purchase - SO BE WARNED AFTER A YEAR TO KEEP AN EYE OUT ON YOUR CARD FOR AMAZON SUBSCRIPTIONS.Screen quality - it is NOT HD. Like the Ring app (that Amazon own and promote as 'HD') Amazon's version of HD doesn't seem to be everyone else's.Poor photo quality - you don't want this to take memorable family snapsImpossible to speak to anyone at Amazon to provide feedback toI also have an iPad Air which cost 10x this. Like comparing a BMW 5 series and a Dacia Sandero, you cannot compare the two. But you may want to pay more if it was just slightly slicker to use and had better features. If the stuff above doesn't bother you and you have incredibly low expectations of quality then this is the perfect 5-star tablet for you. But that low price comes at a cost: hours of frustration. I don't have time for that, personally.\n\n", '2.0 out of 5 stars', 'tastyfish', '7 September 2020']
# ['\nvery poor upgrade from Fire 7"\n', '\n\n  Have used a Fire 7" for some considerable time  and overall have been very pleased with it although admittingly battery life was gradually diminishing so receiving as a Christmas present a Fire 8" was initially very welcome.However as a first time tablet you may be pleased with it but as an upgrade it\'s  poor in comparison.Firstly the casing is now a hard plastic slippery finish unlike the original rubberised finish.The on /off and volume controls now project above the casing and can be easily & inadvertently  touched so you find the volume suddenly being changed or the tablet being switched off, originally they were flush & required a positive press to action. Perhaps the worst aspect is that when you now turn on the tablet it blast out a sound  much to not only your annoyance but everybody in the room with you, and this sound is not controlled by the general volume controls nor can it turned off via settings.The icons once large,  dominant and offering clarity are now small and insignificant. The keyboard is a truly retrograde step, once similar to normal  everyday computer keyboards with proper fonts you now have an excessively large keyboard, all in italic lettering with no divisions !Finally downloading apps such as Met.Ofiice weather and BBC News does not happen and after several attempts and hours you just give up with it.So am I pleased with it, NO, would I recommend it, NO.The only thing that it does offers is a slightly bigger screen but otherwise nothing more or better than my old Fire 7"could do.\n\n', '3.0 out of 5 stars', 'rogert', '30 December 2018']
# ['\nIf you want normal android dont bother...\n', '\n\n\n  Your browser does not support HTML5 video.\n\n\n  \xa0This tablet is likely fine if you dont want play store / regular android on it - so disregard this review IF you are ok with the amazon app store etc.After (easily) installing play store etc.. on this tablet, within 24 hours there were bugs with using it - turns out a unstoppable \'fire os\' software update had broken something - weird typing errors were happening such as instead of typing \'hello how are you\', the tablet would add random characters, so this would appear as \'hhelllo ho$ are Yoou\'Also scaling issues viewing web pages - ironically only happened on amazons website (in \'desktop\' view) - hold your finger down and it zooms in erratically until it canna take no more captain.So, I \'factory reset\' (erase and re-install) and everything was fine, but then... a \'fire os\' update 2 ish weeks later - this cause less issues, but annoyingly, the home and multi task buttons no longer worked (see video).So, rather than do a 2nd factory reset in the space of 2-3 weeks, i will just send this back, either I will get a actual \'android\' tablet or soldier on with my 5.8" phone or get a 6.4" phone.Overall a ok tablet - slower than my s7 phone from 2017. I would say this tablet has 2015 era tech inside, so a bit slow but doable - probably slightly faster than my old ipad mini 2.Screen has quite alot of glare.\n\n', '2.0 out of 5 stars', 'Steve UnboxFresh', '23 December 2019']
# ['\nVery good value for money\n', "\n\n  To be honest I wasn't expecting too much in way of performance of this Fire Tablet when I ordered it, I just wanted a tablet to take on holidays etc that was cheap enough to not worry about getting lost, stolen or broken. I am pleasantly surprised that it is actually quite a good little gadget, it out performs my Lenovo tablet in every way, it connects to wifi and pairs with blue tooth devices without any problems, it runs and plays Amazon Prime videos and Netflix faultlessly. The Amazon app store is more limited than Google Playstore, but it has more than enough apps for my needs and I would think most peoples needs. If I was to make any critisism, it would be that the speaker volume is quite low even when turned up to maximum, however when paired with a cheap blue tooth speaker or headphones the problem is easily solved. All in all, this is a decent tablet for the money.\n\n", '5.0 out of 5 stars', 'Posers Photography', '17 July 2019']
# ['\nSurprisingly worth it + great Entertainment for kids !!!!\n', '\n\n  I am super surprised by the quality of this tablet and functionality  ... We have several iPads in our household. Decided to try this for my 7year old son after some of his apps stopped working on an older iPad. I am very impressed by the Kindle fire for kids app also great tablet for Adults. Obvious room for improvements in built and Amazon App Store however this tablet is very competitive against the iPad given the cost £44.99 on Black Friday sale. We also added Google Play (a very simple process under 5 minutes, available on websites via the Silk browser) which has opened a whole new world of apps including YouTube App compared to the Amazon App Store which is very limited. Also, if you use Amazon additions like Prime, Audible, Music Unlimited, Kindle - the tablet is created to work seamlessly with these. Even though the Amazon shopping app is strangely not as good here or maybe I’m not used to it yet compared to the phone app, I would still rate the Kindle Fire 8 a very high 5 stars!!! Bargain and great value with potential to expand storage to over 200GB what’s not to love? especially compared to the iPad and the games Apple is playing. I would say the Kindle Fire 8 is most useful for children using the Fire for Kids App as the parental controls are very good. There’s a lot to be explored still, so far so good. The special effects thing doesn’t bother me at all, I mostly ignore it and there’s an option to remove it for £10 extra.\n\n', '5.0 out of 5 stars', 'Victoria', '4 December 2019']
# ['\nGreat product but when I buy from Amazon I feel dirty\n', "\n\n  I joined Amazon when I was given a kindle as a gift.  That was a perfect item and I love it; I've bought 200 books. The tech designers and engineers are geniuses.  I've just bought two Fire HD 8 tablets and they are brilliant - I bought them to read my kindle books on and also stream films, bbc iplayer programmes, etc.  However,  I've just read how badly Amazon treat their staff - Tim Bray, a vice-president, has resigned in protest at unethical staff sackings, and once again I'm regretting spending money with this company.  Amazon - I have bought very little from you, I would happily spend thousands if you were a decent employer.  As it is, I can see myself reducing my spend even further and maybe stopping altogether.\n\n", '1.0 out of 5 stars', 'Kentordinary', '7 May 2020']
# ['\nDoes not perform as claimed by Amazon\n', '\n\n  I can not express firmly enough how disappointed I am with this product.I purchase many Amazon products but this is not what I have come to expect. I feel I have been totally mislead. I did a good deal of research into the product and planned to give it to my son for Christmas. It’s marked as having  Alex built in and that it comes with the award winning fire for kids.The issue is that there is a monthly charge for Fire for kids. There is no mention of this in the marketing and the crucial point here is without paying the monthly subscription fee the child can not use the internet from their child profile, so not very useful. The next point is that Alexa only works on the adult profile not the child profile. My son wanted his own Alexa.The final point is that for the first time I experienced terrible customer service from Amazon when I phoned the help line. There seemed to be little to no technical knowledge, in fact they kept putting me on hold whilst they researched their answer, whilst on hold I was doing my own online research and getting information from the Amazon website which the helpline did not seem to be aware of.The final result was they could not help me there is no way to access the internet from a child’s profile without paying for Fire for kids, there is no way to access Alexa from a kids profile and on the 22nd December I am faced with the following choices.Send the product back as it does not perform as advertised but I then need to source a gift for my son before Christmas Day!Keep the product but be forced into paying another subscription. My son should then have internet access but no Alexa.Thank goodness we decided to open up the product and try to get it working before Christmas Day or we would not have discovered these issues.Do not buy this product for a child to use. It does not do what it claims it can without paying additional charges.It would be a well priced product if it could perform as claimed but it doesn’t.Not good enough Amazon!\n\n', '1.0 out of 5 stars', 'Amazon Customer', '22 December 2019']
# ['\nIncredibly impressed\n', '\n\n  We are an “Apple family”, as users of iPhones, macbook and iPads over the last 10+ years however recently we wanted a tablet for our 1 year old for the sake of other passengers, hoping Peppa pig would prevent any airplane meltdowns for his first trip abroad. I’ve always liked my basic kindle for reading but wasn’t sure of the WiFi and apps on a fire. We saw that the kindle fire was on offer at approx £50 so went for it. What a BARGAIN! Fab battery life, great screen and we bought a hefty child proof type case, too. We were able to download episodes of favourite programmes plus some films from Netflix app and amazon prime so that these could be watched without WiFi. You can choose quality level depending on how much memory you want to use (fantastic). I really can’t complain. A fraction of the price of ipads we’ve bought in the past but it did exactly what we wanted it to do i.e on the go entertainment) I’d highly recommend.Although, if your primary purpose is to use the fire as a reading kindle and you want to read in the sun or outside, stick with the usual paper effect kindle - as this would reflect the sun.\n\n', '5.0 out of 5 stars', 'Hannah Williams', '11 September 2019']
# ['\nExcellent bit of Kit\n', '\n\n  Excellent bit of kit. For the amount of money that this costs it is truly a steal!PROS- Quad core processor.- Very decent battery life.- Decent variety of apps for Fire OS (though no YouTube)- Excellent support should you need it.- Speakers are decent.- Quite lightweight.CONS- Screen resolution and brightness could be better.- Camera quality is poor.- OS feels a bit convoluted.Overall a brilliant little device which is ideal to take on holiday or a long journey to watch saved NetFlix or Amazon Video on. However, this is definitely not an iPad replacement.\n\n', '5.0 out of 5 stars', 'Rusty', '17 July 2020']
# ['\nCHEAP and Nearly USELESS!\n', '\n\n  I got the Fire HD 8 Tablet with Alexa, 8" HD (16GB) on £49.99 deal from Amazon (used it for 2 month, and even I returned it)1. TOO SLOW.  2. USES SOME WEIRD AMAZON OPERATING SYSTEM (which is rubbish). 3. HORRIBLE AMAZON APPS.4.  LITTLE FREEDOM TO ACCESS & OPEN SD CARD (your own books/files) and to get them too work.5.  COMES FULL OF ANNOYING AMAZON "POP-UP ADS"Only Good as a cheap, small movie player.  Otherwise USELESS\n\n', '1.0 out of 5 stars', 'Music Man', '23 January 2019']
# ['\nNot good as a Kindle\n', "\n\n  I bought this for use as a Kindle. Though it has many virtues in that respect eh good light from screen and colour illustration comes out in colour, it is poor at this.I find it very difficult to download books I've bought and are in the cloud to the device. It won't set up collections nor can I delete material from the device.Also it works very badly when connected to the Internet.  The Alexa function keeps on trying to take over even though i have it switched off, so that means it's not really usable for any other function either.Basically the software is poor. Hardware seems okay.This may be down to my inability to use it, but there are no instructions.I won't get started on the horror story of local delivery firm Amazon use round here.So don't buy this.\n\n", '2.0 out of 5 stars', 'G. Kent', '11 March 2020']
# ['\nNot fit for purpose\n', "\n\n  I don't want to be rude to Amazon but I have to. This tablet is total and utter junk and I urge nobody to waste money and by this total crap. The build of the tablet is not the problem and the screen is ok, its the function of the tablet that is the problem from the time you take it out the box you have to put up with lag and I mean lag that can last over 30 seconds. Now I know a lot of people are going to say that not much but try it when you are trying to open an email or use any of the other apps after a while it will just get on your nerves. Even getting past the ad screen is a pain as it takes ages.\n\n", '1.0 out of 5 stars', 'Trowbridge', '3 February 2019']
# ['\nUseful piece of kit...\n', "\n\n  On the whole I've found the Fire 8 in general to be a great piece of kit, for me personally It ticks all the boxes. However in the short time that I've had this model (unlike my three previous models), this one unfortunately keeps going off line, losing the internet/wifi signal.  I regularly have to reconnect it to the internet. At first I thought it was my ISP/modem, but they're okay along with my I-phone and another tablet that I use, as well as my Kindle paperwhite, they work fine.I've a few times tried rebooting the Fire 8, tried syncing it, I even reset it to factory settings …. and still it goes offline. Maybe I have a duff one?\n\n", '3.0 out of 5 stars', 'Mark Lewis', '27 June 2019']
# ['\nWORTH EVERY PENNY\n', '\n\n  This was purchased for me as a Birthday Present - to replace my existing tablet - an Apple IPAD, which has seen better days.I was a little bit unsure how the Fire HD would perform compared to the IPAD - but I\'m not disappointed at all. This new tablet does everything that I need it to do - perfect for browsing, watching video and of course reading books. My only niggle is that some of the games that I played on my IPAD - ie Golf Clash - won\'t run very well on the Fire, the game is very "jerky" to say the least. But as I say - this is a small niggle - the pros of my new tablet far outweigh the cons.\n\n', '5.0 out of 5 stars', 'AlexB', '10 February 2019']
# ['\nDid not work with BT Hub\n', '\n\n  I bought this product for my Mum and mother in law. great little product but I am afraid it would not connect to internet. Even though connected to wifi it would not go on to internet. It seems as it has problem with BT hubs.I tried to get help on line but with no joy. At the end gave up and returned the product\n\n', '1.0 out of 5 stars', 'Consumer', '28 August 2019']
# ['\nNot a great device slow laggy washed out screen\n', '\n\n  Screen is washed out and an awful viewing experience which is so noticeable going from that to iPad or phone,constantly gets stuck in show mode and I have to eventually restart...ha if it lets you do that even ridiculously slow and laggy UI is clunky to the point it\'s laughable it\'s like going back in time to netbook standards.Constantly pinging me notifications about delivered parcels even though I remove the notification.i paid more money so I didn\'t have to have one of their "special offer" one = spy on you and bombard you with crappy targeted ads can\'t imagine how bad that one would have been.All in all pretty disappointed and I\'m guessing the good reviews come from people that don\'t normally buy the top end of tech and not used to a flowing UI and fast response time on an hd screen.So to finish this is budget and it shows it\n\n', '1.0 out of 5 stars', 'Amazon Customer', '7 January 2019']
# ['\nDurable good quality, value for money, perfect for kids.\n', "\n\n  For the price these can be got for, they are fantastic for the kids,  great battery life usually 7-8 hours of constant use, a good clear screen and extremely durable, for what you can get in an android tablet at the same price point it's a no brainer. Although I would love to see android on this device due to more app availability,  my boys have gotten by just fine with what's available in the app store. Does not come with a plug and I would recommend getting a fast charging one.\n\n", '5.0 out of 5 stars', 'Bex and Perry', '29 November 2019']
# ['\nFire HD8 Tablet.\n', "\n\n  I had been a bit wary of buying this tablet at it seemed too cheap and I was afraid it would be very limited. I couldn't have been more wrong. It does everything my previous Samsung Galaxy Tab could do and downloading the apps I wanted was very easy. I bought the 16 GB version but increased this by transferring the SD card from my Samsung. I also got the one with special offers but don't find the advert on the home screen a problem and not worth £10.00 to have it removed. As all my Kindle books are automatically transferred when you set up I now use this instead of my Kindle which is starting to be a bit erratic. The only downside I've found is that I can't transfer music from my iTunes library, which is why I've given it 4 stars, although apparently there are some YouTube videos which show you how to do this. Overall I am very happy and now have a tablet which has replaced my previous tablet and Kindle at less than half the cost.\n\n", '4.0 out of 5 stars', 'John Carter', '5 November 2019']
# ['\nUnbeatable at the price\n', "\n\n  Purchased as a replacement for my now aged but much loved Kobo Arc, The Fire HD 8 is unbeatable for the money, especially at the much reduced Black Friday price. Although very Amazon and well worth paying extra to be more ad free, it's simple to load the Google Play store (plenty of how to do it hints on the web) if you want some of the apps not available from Amazon. OK, it's not an ipad but if you want to surf the web, do some social media, play games,watch film and TV, send emails, Skype etc etc, etc why would you need to spend more?\n\n", '5.0 out of 5 stars', 'F P CORRIGAN', '12 December 2019']
# ['\nA really nice little tablet\n', "\n\n  This is a really nice tablet at a very reasonable price.  I actually purchased it on offer, so it really was a great buy.  Having said that I purchased the same tablet earlier in the year at the full price and still consider it to be well worth the cost.  Its very easy to use with lots of really good apps.  The screen size is good with nice clear viewing.  The sound is excellent as is the all round general performance.  It has a front and back camera making it perfect for skyping friends and taking photos.  I bought it for my son who uses it to play games and watch movies etc.  As well as being able to download apps from Amazon I also was able to quickly download the Netflix app and the Sky Go app giving him a huge wealth of things to watch.For the price you just can't beat this tablet.  Highly recommend.\n\n", '5.0 out of 5 stars', 'Jaxlarkabout', '24 February 2020']
# ['\nI love it\n', "\n\n  If you got this tablet at £79.99 then you got a bargain. If you paid less then it's the best money you have ever spent with Amazon. My very old IPad is well past its sell by date and I replaced it with the Fire HD 8. I can't say just how good this tablet is for the money but I'm really impressed with the quality and sound.If you are a prime member then you get all the benefits like music and kindle as well as prime video.What else can I say other than thanks Amazon I love it.\n\n", '5.0 out of 5 stars', 'T. KELLY', '6 December 2019']
# ['\nWhat’s not to like!!!!!!\n', '\n\n  My old Fire Tablet of 2015 gave up the ghost, to be fair I certainly had my monies worth out of it! I watch movies and tv programmes on it, read books, check emails, listen music so for the money the last one for me was a good deal! My husband has an ipad, his usage is just the same but his costs ££££ more but the clarity on his ipad screen was better than the Fire, but I could live with that for the money.BUT THE NEW FIRE IS LIKE FOR LIKE IN CLARITY!!!!I am very impressed with the new Fire Tablet, it does all things I want it to like my old one but the quality when watching movies etc is awesome and a match for my hubbies ipad - All for just £79.99!!!! You can’t knock it!!!!!\n\n', '5.0 out of 5 stars', 'B.Lee', '19 May 2019']
# ['\nGreat value!  Win! Win!\n', "\n\n  I previously had a Kindle Fire 8GB bought on the first black Friday sale for £40.  I couldn't have been more pleased with it.  You can't expect things to last forever and so I have had to purchase another this time with more memory.  The camera on this is better and obviously I now have more memory, for the price I paid I am well pleased.  The Fire does emails, Facebook, Ebay, Messenger stores files.  It's such a small item, a bit bigger than a mobile phone so nice to show holiday pics on without getting out a large lap top.  I can download books to read when I am travelling abroad, take pics and email friends.  A lot of gadget for an amazing price.  I am in my 60's and this is easy to use for someone with little computer knowledge of even a child to keep in contact with friends.  Win.  Win.\n\n", '5.0 out of 5 stars', 'chopsuey', '7 April 2019']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-e7117d8f73a8> in <module>
#       1 while True:
# ----> 2     data=getdata(url)
#       3     url = getnext_page(data)
#       4     if not url:
#       5         break
#
# <ipython-input-28-521a4f1385c6> in getdata(url)
#       3             'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36'
#       4         }
# ----> 5     req = requests.get(url, headers = headers)
#       6     soup = bs(req.content,'html.parser')
#       7     title = soup.find_all('a',class_='review-title-content')
#
# ~/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379         # Trigger any extra validation we need to do.
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#     383             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     976         # Force connect early to allow us to validate the connection.
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#     980         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     307     def connect(self):
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#     311
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     157
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59     family = allowed_gai_family()
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#      63         sock = None
#
# ~/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     916     # and socket type values to enum constants.
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#     920         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:
